# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Get keys from my file
from api_keys import weather_api_key
from api_keys import g_key

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Set Output File (CSV) path
#
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations and zip into a list of tuples
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination using the Citypy package to return a unique city and country code
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Combine the two lists into a list of tuples using the zip function
city_country = zip(cities,countries)

# Print the city count to confirm sufficient count ( Greater than 500 )
print(len(cities))
# Out:
# 607

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : hermanus
# Processing Record 2 of Set 1 : cacequi
# Processing Record 3 of Set 1 : honningsvag
# City not found. Skipping...
# Processing Record 4 of Set 1 : jamestown
# Processing Record 5 of Set 1 : avarua
# Processing Record 6 of Set 1 : barrow
# Processing Record 7 of Set 1 : sitka
# Processing Record 8 of Set 1 : basco
# Processing Record 9 of Set 1 : kloulklubed
# Processing Record 10 of Set 1 : tasiilaq
# Processing Record 11 of Set 1 : mount gambier
# Processing Record 12 of Set 1 : eureka
# Processing Record 13 of Set 1 : upernavik
# City not found. Skipping...
# Processing Record 14 of Set 1 : port alfred
# Processing Record 15 of Set 1 : terrace
# Processing Record 16 of Set 1 : ugoofaaru
# Processing Record 17 of Set 1 : bredasdorp
# Processing Record 18 of Set 1 : ushuaia
# Processing Record 19 of Set 1 : bhainsdehi
# Processing Record 20 of Set 1 : faanui
# Processing Record 21 of Set 1 : puerto ayora
# Processing Record 22 of Set 1 : grand gaube
# Processing Record 23 of Set 1 : aksay
# Processing Record 24 of Set 1 : bethel
# Processing Record 25 of Set 1 : yulara
# Processing Record 26 of Set 1 : longyearbyen
# Processing Record 27 of Set 1 : bluff
# Processing Record 28 of Set 1 : aswan
# Processing Record 29 of Set 1 : mahanoro
# Processing Record 30 of Set 1 : kodiak
# Processing Record 31 of Set 1 : yellowknife
# Processing Record 32 of Set 1 : jatiroto
# Processing Record 33 of Set 1 : narsaq
# Processing Record 34 of Set 1 : belyy yar
# Processing Record 35 of Set 1 : qaanaaq
# Processing Record 36 of Set 1 : okhotsk
# Processing Record 37 of Set 1 : makakilo city
# Processing Record 38 of Set 1 : yashkul
# City not found. Skipping...
# Processing Record 39 of Set 1 : saint-francois
# Processing Record 40 of Set 1 : port hardy
# Processing Record 41 of Set 1 : georgetown
# Processing Record 42 of Set 1 : balkhash
# Processing Record 43 of Set 1 : xinyu
# Processing Record 44 of Set 1 : sidney
# Processing Record 45 of Set 1 : victoria
# Processing Record 46 of Set 1 : mataura
# Processing Record 47 of Set 1 : kapaa
# Processing Record 48 of Set 1 : buala
# Processing Record 49 of Set 1 : punta arenas
# Processing Record 50 of Set 1 : rikitea
# Processing Record 0 of Set 2 : srednekolymsk
# City not found. Skipping...
# Processing Record 1 of Set 2 : severo-kurilsk
# Processing Record 2 of Set 2 : kruisfontein
# Processing Record 3 of Set 2 : cape town
# Processing Record 4 of Set 2 : antofagasta
# Processing Record 5 of Set 2 : butaritari
# Processing Record 6 of Set 2 : pisco
# Processing Record 7 of Set 2 : katsuura
# Processing Record 8 of Set 2 : bowen
# Processing Record 44 of Set 4 : amberley
# Processing Record 45 of Set 4 : airai
# Processing Record 46 of Set 4 : irawan
# Processing Record 47 of Set 4 : salalah
# Processing Record 48 of Set 4 : tateyama
# Processing Record 49 of Set 4 : te anau
# Processing Record 50 of Set 4 : san policarpo
# Processing Record 0 of Set 5 : puerto escondido
# Processing Record 1 of Set 5 : huaicheng
# Processing Record 2 of Set 5 : riyadh
# Processing Record 3 of Set 5 : souillac
# Processing Record 4 of Set 5 : fereydun kenar
# Processing Record 5 of Set 5 : clyde river
# Processing Record 6 of Set 5 : kavieng
# Processing Record 7 of Set 5 : port elizabeth
# Processing Record 8 of Set 5 : killybegs
# Processing Record 9 of Set 5 : saskylakh
# Processing Record 10 of Set 5 : adrar
# Processing Record 11 of Set 5 : sakaiminato
# Processing Record 12 of Set 5 : volchikha
# City not found. Skipping...
# Processing Record 13 of Set 5 : thohoyandou
# Processing Record 14 of Set 5 : camacha
# Processing Record 15 of Set 5 : khandyga
# Processing Record 16 of Set 5 : sorong
# City not found. Skipping...
# Processing Record 17 of Set 5 : ust-koksa
# Processing Record 18 of Set 5 : kozhva
# Processing Record 19 of Set 5 : ucluelet
# Processing Record 20 of Set 5 : saint-pierre
# Processing Record 21 of Set 5 : ardakan
# Processing Record 22 of Set 5 : muzhi
# Processing Record 23 of Set 5 : caravelas
# Processing Record 24 of Set 5 : takaka
# Processing Record 25 of Set 5 : buin
# Processing Record 26 of Set 5 : kalmunai
# Processing Record 27 of Set 5 : hamilton
# Processing Record 28 of Set 5 : altagracia de orituco
# Processing Record 29 of Set 5 : akyab
# Processing Record 30 of Set 5 : yumen
# Processing Record 31 of Set 5 : coihaique
# Processing Record 32 of Set 5 : kamenka
# Processing Record 33 of Set 5 : mehamn
# Processing Record 34 of Set 5 : aykhal
# Processing Record 35 of Set 5 : lavrentiya
# Processing Record 36 of Set 5 : mount pleasant
# City not found. Skipping...
# Processing Record 37 of Set 5 : tiksi
# Processing Record 38 of Set 5 : verkhnyaya toyma
# Processing Record 39 of Set 5 : sladkovo
# Processing Record 40 of Set 5 : aksarka
# Processing Record 41 of Set 5 : trat
# Processing Record 42 of Set 5 : fortuna
# Processing Record 43 of Set 5 : vilyuysk
# Processing Record 44 of Set 5 : tahe
# City not found. Skipping...
# Processing Record 45 of Set 5 : norman wells
# Processing Record 46 of Set 5 : comodoro rivadavia
# Processing Record 47 of Set 5 : puerto madryn
# Processing Record 48 of Set 5 : pastavy
# Processing Record 49 of Set 5 : mangochi
# Processing Record 50 of Set 5 : kjollefjord
# Processing Record 0 of Set 6 : mnogovershinnyy
# City not found. Skipping...
# Processing Record 1 of Set 6 : matara
# Processing Record 2 of Set 6 : huilong
# Processing Record 3 of Set 6 : nabire
# Processing Record 4 of Set 6 : yeppoon
# Processing Record 5 of Set 6 : kovdor
# Processing Record 6 of Set 6 : tongren
# Processing Record 7 of Set 6 : mogadishu
# Processing Record 8 of Set 6 : geraldton
# Processing Record 9 of Set 6 : santa cruz
# Processing Record 10 of Set 6 : odweyne
# Processing Record 11 of Set 6 : hay river
# Processing Record 12 of Set 6 : price
# Processing Record 13 of Set 6 : tessalit
# Processing Record 14 of Set 6 : george town
# Processing Record 15 of Set 6 : ostrovnoy
# City not found. Skipping...
# Processing Record 16 of Set 6 : puerto leguizamo
# Processing Record 17 of Set 6 : campos
# Processing Record 18 of Set 6 : itarema
# Processing Record 19 of Set 6 : haines junction
# Processing Record 20 of Set 6 : hidalgo
# Processing Record 21 of Set 6 : gilgit
# Processing Record 22 of Set 6 : lasa
# Processing Record 23 of Set 6 : mandiana
# Processing Record 24 of Set 6 : pacifica
# Processing Record 25 of Set 6 : vestmannaeyjar
# Processing Record 26 of Set 6 : meulaboh
# Processing Record 27 of Set 6 : neuquen
# City not found. Skipping...
# Processing Record 28 of Set 6 : kirakira
# Processing Record 29 of Set 6 : pergamino
# Processing Record 30 of Set 6 : pevek
# Processing Record 31 of Set 6 : shenjiamen
# Processing Record 32 of Set 6 : oranjemund
# Processing Record 33 of Set 6 : spencer
# Processing Record 34 of Set 6 : lebu
# Processing Record 35 of Set 6 : beringovskiy
# Processing Record 36 of Set 6 : frontera
# Processing Record 37 of Set 6 : tiarei
# Processing Record 38 of Set 6 : barao de melgaco
# Processing Record 39 of Set 6 : cap malheureux
# City not found. Skipping...
# Processing Record 40 of Set 6 : talcahuano
# Processing Record 41 of Set 6 : harper
# Processing Record 42 of Set 6 : sao joao da barra
# Processing Record 43 of Set 6 : chapais
# Processing Record 44 of Set 6 : waipawa
# Processing Record 45 of Set 6 : pavlovsk
# Processing Record 46 of Set 6 : asau
# Processing Record 47 of Set 6 : zhezkazgan
# Processing Record 48 of Set 6 : bull savanna
# Processing Record 49 of Set 6 : dong hoi
# Processing Record 50 of Set 6 : baindur
# Processing Record 0 of Set 7 : sao filipe
# Processing Record 1 of Set 7 : manga
# Processing Record 2 of Set 7 : halifax
# City not found. Skipping...
# Processing Record 3 of Set 7 : kahului
# Processing Record 4 of Set 7 : zhigansk
# Processing Record 5 of Set 7 : nushki
# Processing Record 6 of Set 7 : normandin
# Processing Record 7 of Set 7 : port-gentil
# Processing Record 8 of Set 7 : teya
# Processing Record 9 of Set 7 : hervey bay
# Processing Record 10 of Set 7 : guaruja
# Processing Record 11 of Set 7 : petropavlovsk-kamchatskiy
# Processing Record 12 of Set 7 : saint-philippe
# Processing Record 13 of Set 7 : kotra
# Processing Record 14 of Set 7 : moorhead
# Processing Record 15 of Set 7 : chumikan
# Processing Record 16 of Set 7 : margate
# Processing Record 17 of Set 7 : libourne
# Processing Record 18 of Set 7 : merritt island
# Processing Record 19 of Set 7 : bayan
# Processing Record 20 of Set 7 : birjand
# City not found. Skipping...
# Processing Record 21 of Set 7 : nerang
# Processing Record 22 of Set 7 : mbini
# Processing Record 23 of Set 7 : boguchany
# Processing Record 24 of Set 7 : manzanillo
# Processing Record 27 of Set 11 : grand bank
# Processing Record 28 of Set 11 : lerwick
# Processing Record 29 of Set 11 : ndele
# City not found. Skipping...
# Processing Record 30 of Set 11 : show low
# Processing Record 31 of Set 11 : beisfjord
# Processing Record 32 of Set 11 : rio maior
# Processing Record 33 of Set 11 : nanakuli
# Processing Record 34 of Set 11 : caibarien
# Processing Record 35 of Set 11 : boralday
# Processing Record 36 of Set 11 : colares
# Processing Record 37 of Set 11 : kushima
# Processing Record 38 of Set 11 : fairbanks
# Processing Record 39 of Set 11 : solnechnyy
# Processing Record 40 of Set 11 : manono
# Processing Record 41 of Set 11 : snasa
# Processing Record 42 of Set 11 : noormarkku
# Processing Record 43 of Set 11 : imeni poliny osipenko
# Processing Record 44 of Set 11 : palmer
# Processing Record 45 of Set 11 : bozoum
# Processing Record 46 of Set 11 : westport
# Processing Record 47 of Set 11 : bilibino
# Processing Record 48 of Set 11 : mangla
# Processing Record 49 of Set 11 : mustasaari
# Processing Record 50 of Set 11 : mizan teferi
# Processing Record 0 of Set 12 : teruel
# Processing Record 1 of Set 12 : bamberg
# Processing Record 2 of Set 12 : uige
# Processing Record 3 of Set 12 : wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Covert Raw data to DataFrame() and store to "weather_dict" as the the following 
# format
# City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Humidity" : humidity_list,
                "Cloudiness" : cloudiness_list,
                "Wind Speed" : wind_speed_list,
                "Country" : country_list,
                "Date" : date_list                
})


# Display the Data Frame
weather_dict.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.42   19.23     46.99        95          31        6.55
# 1      Cacequi -29.88  -54.83     52.54        78           0        3.18
# 2  Honningsvåg  70.98   25.97     48.94        87          34       17.16
# 3    Jamestown  42.10  -79.24     73.00        64          90       14.99
# 4       Avarua -21.21 -159.78     77.00        73          12       21.92
#
#   Country        Date
# 0      ZA  1601346634
# 1      BR  1601346634
# 2      NO  1601346634
# 3      US  1601346492
# 4      CK  1601346635

# %%
# Save city data into a csv file for further analysis and plotting
#
weather_dict.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check if there is any city that have humidity > 100%
#
weather_dict.loc[weather_dict["Humidity"] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
weather_dict_index = weather_dict.index[weather_dict["Humidity"] > 100]
weather_dict_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#
weather_dict = weather_dict.drop(weather_dict_index)
weather_dict.dropna(inplace = True) 
weather_dict.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.42   19.23     46.99        95          31        6.55
# 1      Cacequi -29.88  -54.83     52.54        78           0        3.18
# 2  Honningsvåg  70.98   25.97     48.94        87          34       17.16
# 3    Jamestown  42.10  -79.24     73.00        64          90       14.99
# 4       Avarua -21.21 -159.78     77.00        73          12       21.92
# 5       Barrow  71.29 -156.79     30.20        86          90        9.17
# 6        Sitka  57.05 -135.33     53.60        76          40        6.93
# 7        Basco  20.45  121.97     82.53        80          48       10.67
# 8  Kloulklubed   7.04  134.26     86.00        70          75        5.82
# 9     Tasiilaq  65.61  -37.64     30.20        92          76        3.36
#
#   Country        Date
# 0      ZA  1601346634
# 1      BR  1601346634
# 2      NO  1601346634
# 3      US  1601346492
# 4      CK  1601346635
# 5      US  1601346635
# 6      US  1601346636
# 7      PH  1601346636
# 8      PW  1601346637
# 9      GL  1601346637

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot: Latitude vs. Temperature 
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], 
            facecolor = "steelblue", edgecolor = "blue")

# Title 
plt.title("Latitude vs. Max Temperature (Date: 09/28/20)")

# x axis label
plt.xlabel("Laitude")

# y axis label
plt.ylabel("Max Temperature (F)")

# set grid line
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the plotted figures as .pngs
#
plt.savefig("../Images/Latitude-vs-MaxTemperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot: Latitude vs. Humidity Plot
#
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], 
            facecolor = "steelblue", edgecolor = "blue")

# Title
plt.title("Latitude vs. Humidity (Date: 09/28/20)")

# x axis label
plt.xlabel("Laitude")

# y axis label
plt.ylabel("Humidity (%)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the plotted figure as .pngs
plt.savefig("../Images/City-Latitude-vs-Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot: Latitude vs. Cloudiness 
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], 
            facecolor = "steelblue", edgecolor = "blue")

# Set title
plt.title("City Latitude vs. Cloudiness (Date: 09/28/20)")

# x axis label
plt.xlabel("Laitude")

# y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the plotted figure as .pngs
plt.savefig("../Images/Latitude-vs-Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot: Latitude vs. Wind Speed 
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], 
            facecolor = "steelblue", edgecolor = "blue")
plt.title("City Latitude vs. Wind Speed (mph) (09/28/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')


# Save the plotted figure as .pngs
plt.savefig("../Images/Latitude-vs-WindSpeed(mph.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Function to creating linear regression and scatter plot
# Linear regression func
#
def linear_regress(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Fuction for annotating plot
#
def annotate_plt(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="blue")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call annotation func
#
annotate_plt(get_regress, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp(F)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/NorthernHemisphere-MaxTemp-vs-LatitudeLinearRegression.png")
# Out:
# The r-squared is : -0.84

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call annotate func
annotate_plt(get_regress, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp(F)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/SouthernHemisphere-MaxTemp-vs-Latitude-LinearRegression.png")
# Out:
# The r-squared is : 0.74

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call annotate func
annotate_plt(get_regress, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity(%)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/Northern Hemisphere-Humidity(%)-vs-Latitude-Linear-Regression.png")
# Out:
# The r-squared is : 0.07

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call annotate func
annotate_plt(get_regress, -40, 50)

# Title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# xlabel
plt.xlabel("Latitude")

# ylabel
plt.ylabel("Humidity(%)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/SouthernHemisphere-Humidity(%)-vs-LatitudeLinearRegression.png")
# Out:
# The r-squared is : 0.08

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call annotate func
annotate_plt(get_regress, 30, 40)

# Title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# xlabel
plt.xlabel("Latitude")

# ylabel
plt.ylabel("Cloudiness(%)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.03

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call annotate func
annotate_plt(get_regress, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# xlabel
plt.xlabel("Latitude")

# ylabel
plt.ylabel("Cloudiness(%)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.06

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call annotate func
annotate_plt(get_regress, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed(mph)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/Northern Hemisphere-WindSpeed-vs-Latitude-Linear-Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call function 
get_regress = linear_regress(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call annotate func
annotate_plt(get_regress, -30, 15)

# title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# xlabel
plt.xlabel("Latitude")

# ylabel
plt.ylabel("Wind Speed (mph)")

# Set grid 
plt.grid(linestyle='-', linewidth=1.5, alpha = 0.5, color='r')

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.22
